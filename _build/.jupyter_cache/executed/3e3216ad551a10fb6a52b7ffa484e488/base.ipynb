# %%
from graphviz import Graph
dot = Graph()
dot.attr(rankdir='LR')
dot.edges(['12', '13', '35', '23', '14', '24', '33'])
dot

# %%
from graphviz import Digraph
dot = Digraph()
dot.attr(rankdir='LR')
dot.edges(['12', '31', '35', '23', '14', '42', '33'])
dot
