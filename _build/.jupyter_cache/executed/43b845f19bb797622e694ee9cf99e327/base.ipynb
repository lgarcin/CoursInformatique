# %%
import networkx as nx
G = nx.Graph()
G.add_edges_from([(1,2), (1,3), (3,5), (2,3), (1,4), (2,4), (3,3)])
nx.draw_circular(G, with_labels=True, font_weight="bold", font_size=20, node_size=500)

# %%
[e for e in G.edges]
# Out:
# [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 5), (3, 3)]

# %%
import networkx as nx
G = nx.DiGraph()
G.add_edges_from([(1,2), (1,3), (3,5), (2,3), (1,4), (2,4), (3,3)])
nx.draw(G, with_labels=True, font_weight="bold", font_size=20, node_size=500)

# %%
from graphviz import Digraph
dot = Digraph()
dot.attr(rankdir='LR')
dot.edges(['12', '31', '35', '23', '14', '42', '33'])
dot
